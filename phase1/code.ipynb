# %%
# !pip install pandas numpy scipy scikit-learn matplotlib seaborn imbalanced-learn requests
# Out:
# ...
#
#    ---------------------------------------- 0/2 [sklearn-compat]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    ---------------------------------------- 2/2 [imbalanced-learn]
#
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python phase1_pipeline.py
# Out:
# Project root: D:\arshad\term2\MachinLearning\fainalProject\ML_final\phase1
# Cache root: D:\arshad\term2\MachinLearning\fainalProject\ML_final\cache
# Seed: 42
#
# --- Fetching available seasons for competition ---
# Found 18 season(s): ['2020/2021', '2019/2020', '2018/2019', '2017/2018', '2016/2017', '2015/2016', '2014/2015', '2013/2014', '2012/2013', '2011/2012', '2010/2011', '2009/2010', '2008/2009', '2007/2008', '2006/2007', '2005/2006', '2004/2005', '1973/1974']
# Selected seasons for experiments: ['2017/2018', '2018/2019', '2019/2020', '2020/2021']
# Final Config: {
#   "DATA_MODE": "statsbomb",
#   "COMPETITION_NAME": "La Liga",
#   "SEASONS": [
#     "2017/2018",
#     "2018/2019",
#     "2019/2020",
#     "2020/2021"
#   ],
#   "MAX_MATCHES": null,
#   "INCLUDE_THREE_SIXTY": true,
#   "ROLLING_WINDOW": 5,
#   "MIN_HISTORY": 1,
#   "SNAPSHOT_MINUTES": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     40,
#     45,
#     50,
#     55,
#     60,
# ...

# %%
import os

print(os.listdir("outputs"))
# Out:
# ['class_distribution_by_season.png', 'cross_season_balanced_accuracy.png', 'cross_season_experiment_results.csv', 'data_integration_report.csv', 'feature_ablation.png', 'feature_ablation_results.csv', 'feature_correlation.png', 'gmm_diagnostics_experiment_1.csv', 'gmm_diagnostics_experiment_2.csv', 'gmm_diagnostics_experiment_3.csv', 'in_play_snapshots_all_seasons.csv', 'leakage_audit.csv', 'odds_coverage.csv', 'odds_excluded_matches.csv', 'pre_match_features_all_seasons.csv', 'run_metadata.json']

# %%
import pandas as pd

result = pd.read_csv(
    "outputs/feature_ablation_results.csv"
)

result
# Out:
#                Feature_Set  Number_of_Features  Accuracy
# 0                Form only                  99  0.565217
# 1            Form + Attack                 105  0.565217
# 2  Form + Attack + Defense                 107  0.565217
# 3             All Features                 123  0.565217

# %%
from IPython.display import Image, display

display(
    Image(
        filename="outputs/feature_ablation.png"
    )
)

# %%
from IPython.display import Image, display

display(
    Image(
        filename="outputs/feature_ablation.png"
    )
)

# %%
import os
from IPython.display import Image, display


for f in os.listdir("outputs"):

    if f.endswith(".png"):

        print("\n",f)

        display(
            Image(
                filename="outputs/"+f
            )
        )
